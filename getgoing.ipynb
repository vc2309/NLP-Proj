# %%
import nltk

# %%
print("hi")
# Out:
# hi

# %%
from nltk.corpus import inaugural

# %%
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
all = inaugural.fileids()

# %%
all[1].sents()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-2b7ee3a677a7> in <module>()
# ----> 1 all[1].sents()
#
# AttributeError: 'str' object has no attribute 'sents'

# %%
import nltk
from nltk.corpus import inaugural
from __future__ import division
for item in all:
    print(nltk.corpus.inaugural.words(item)/nltk.corpus.inaugural.sents(item))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8251290c7fcf> in <module>()
#       3 from __future__ import division
#       4 for item in all:
# ----> 5     print(nltk.corpus.inaugural.words(item)/nltk.corpus.inaugural.sents(item))
#
# TypeError: unsupported operand type(s) for /: 'StreamBackedCorpusView' and 'StreamBackedCorpusView'

# %%
import nltk
from nltk.corpus import inaugural
from __future__ import division
for item in all:
    w=len(nltk.corpus.inaugural.words(item))
    s=len(nltk.corpus.inaugural.sents(item))
    print(w/s)
# Out:
# 64.08333333333333
# 36.75
# 69.86486486486487
# 46.07142857142857
# 52.977777777777774
# 60.23809523809524
# 39.515151515151516
# 30.270491803278688
# 38.054263565891475
# 42.567567567567565
# 48.32
# 42.233333333333334
# 43.90526315789474
# 43.642857142857146
# 33.96078431372549
# 53.72727272727273
# 35.16346153846154
# 34.80898876404494
# 29.02173913043478
# 29.074074074074073
# 30.21951219512195
# 33.59090909090909
# 46.16949152542373
# 28.919642857142858
# 41.54545454545455
# 30.254777070063696
# 37.12068965517241
# 33.62307692307692
# 24.5
# 33.06060606060606
# 36.76729559748428
# 28.014705882352942
# 27.6
# 25.20805369127517
# 22.548223350253807
# 24.620253164556964
# 24.270588235294117
# 21.03125
# 22.58823529411765
# 24.5
# 21.79310344827586
# 22.5609756097561
# 20.83695652173913
# 29.73076923076923
# 18.24468085106383
# 22.87735849056604
# 29.391304347826086
# 26.037735849056602
# 22.055118110236222
# 23.38095238095238
# 18.71034482758621
# 22.901234567901234
# ...

# %%
import pandas as pd

# %%
wr = pd.DataFrame
wr.rate = [len(nltk.corpus.inaugural.words(item)) for item in all]
wr.name =[item for item in all]
import matplotlib.pyplot as plt

# %%
wr.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6cbd66aac1d7> in <module>()
# ----> 1 wr.plot()
#
# TypeError: __init__() missing 1 required positional argument: 'data'

# %%
plt.plot(wr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/vishnuchopra/anaconda3/envs/vcenv/lib/python3.5/site-packages/matplotlib/cbook.py in index_of(y)
#    2547     try:
# -> 2548         return y.index.values, y.values
#    2549     except AttributeError:
#
# pandas/_libs/src/properties.pyx in pandas._libs.lib.AxisProperty.__get__ (pandas/_libs/lib.c:45000)()
#
# AttributeError: 'NoneType' object has no attribute '_data'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-440ac2ce7b89> in <module>()
# ----> 1 plt.plot(wr)
#
# /Users/vishnuchopra/anaconda3/envs/vcenv/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
# ...

# %%
pd.plot(wr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-7ad27d07d98a> in <module>()
# ----> 1 pd.plot(wr)
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
wr.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-928169833a8b> in <module>()
# ----> 1 wr.head()
#
# TypeError: head() missing 1 required positional argument: 'self'

# %%
print(wr)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import nltk
from nltk.util import ngrams as ng
text="what it do young sav"
toks=nltk.word_tokenize(text)

# %%
toks
# Out:
# ['what', 'it', 'do', 'young', 'sav']

# %%
nltk.bigrams(toks)
# Out:
# <generator object bigrams at 0x1127c0360>

# %%
print(nltk.bigrams(toks))
# Out:
# <generator object bigrams at 0x1127c0620>

# %%
ng(toks,2)
# Out:
# <generator object ngrams at 0x11275ed58>

# %%
n=ng(toks,2)

# %%
print(n)
# Out:
# <generator object ngrams at 0x11275ee08>

# %%
for item in n:
    print( item)
# Out:
# ('what', 'it')
# ('it', 'do')
# ('do', 'young')
# ('young', 'sav')

# %%
import nltk.corpus.gutenberg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-4f071d712e1e> in <module>()
# ----> 1 import nltk.corpus.gutenberg
#
# ImportError: No module named 'nltk.corpus.gutenberg'

# %%
alice = nltk.corpus.gutenberg.words("carroll-alice.txt")

# %%
import re
w=[word for word in alice if re.search('^[aeiou]c.*y$',word)]
print(w)
# Out:
# ['actually', 'occasionally', 'accidentally']

# %%
import nltk

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
nltk.corpus.gutenberg
# Out:
# <PlaintextCorpusReader in '/Users/vishnuchopra/nltk_data/corpora/gutenberg'>

# %%
gut=nltk.corpus.gutenberg

# %%
alice = gut.words("carroll-alice.txt")

# %%
alice
# Out:
# ['[', 'Alice', "'", 's', 'Adventures', 'in', ...]

# %%
len(alice)
# Out:
# 34110

# %%
alice_new = [word.lower() for word in alice if word.isalpha()]
# tags=[nltk.pos_tag(word) for word in alice_new if word in ['over','spoke','answer']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-8affce14d3a9> in <module>()
#       1 import nltk
# ----> 2 alice_new = [word.lower() for word in alice if word.isalpha()]
#       3 # tags=[nltk.pos_tag(word) for word in alice_new if word in ['over','spoke','answer']]
#
# <ipython-input-20-8affce14d3a9> in <listcomp>(.0)
#       1 import nltk
# ----> 2 alice_new = [word.lower() for word in alice if word.isalpha()]
#       3 # tags=[nltk.pos_tag(word) for word in alice_new if word in ['over','spoke','answer']]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'isalpha'

# %%
tags
# Out:
# []

# %%
story=gut.words("bryant-stories.txt")

# %%
story
# Out:
# ['[', 'Stories', 'to', 'Tell', 'to', 'Children', 'by', ...]

# %%
stn=[word.lower() for word in story if word.isalpha()]

# %%
stn
# Out:
# ['stories',
#  'to',
#  'tell',
#  'to',
#  'children',
#  'by',
#  'sara',
#  'cone',
#  'bryant',
#  'two',
#  'little',
#  'riddles',
#  'in',
#  'rhyme',
#  'there',
#  's',
#  'a',
#  'garden',
#  'that',
#  'i',
#  'ken',
#  'full',
#  'of',
#  'little',
#  'gentlemen',
#  'little',
#  'caps',
#  'of',
#  'blue',
#  'they',
#  'wear',
#  'and',
#  'green',
#  'ribbons',
#  'very',
#  'fair',
#  'flax',
#  'from',
#  'house',
#  'to',
#  'house',
#  'he',
#  'goes',
#  'a',
#  'messenger',
#  'small',
#  'and',
#  'slight',
#  'and',
#  'whether',
#  'it',
#  'rains',
#  'or',
#  'snows',
#  'he',
#  'sleeps',
#  'outside',
#  'in',
#  'the',
#  'night',
#  'the',
#  'path',
#  'the',
#  'little',
#  'yellow',
#  'tulip',
#  'once',
#  'there',
#  'was',
#  'a',
#  'little',
#  'yellow',
#  'tulip',
#  'and',
#  'she',
#  'lived',
#  'down',
#  'in',
#  'a',
#  'little',
#  'dark',
#  'house',
#  'under',
#  'the',
#  'ground',
#  'one',
#  'day',
#  'she',
#  'was',
# ...

# %%
tags=nltk.pos_tag(stn,tagset="universal")

# %%
tags
# Out:
# [('stories', 'NOUN'),
#  ('to', 'PRT'),
#  ('tell', 'VERB'),
#  ('to', 'PRT'),
#  ('children', 'NOUN'),
#  ('by', 'ADP'),
#  ('sara', 'NOUN'),
#  ('cone', 'NOUN'),
#  ('bryant', 'ADJ'),
#  ('two', 'NUM'),
#  ('little', 'ADJ'),
#  ('riddles', 'NOUN'),
#  ('in', 'ADP'),
#  ('rhyme', 'NOUN'),
#  ('there', 'DET'),
#  ('s', 'VERB'),
#  ('a', 'DET'),
#  ('garden', 'NOUN'),
#  ('that', 'ADP'),
#  ('i', 'NOUN'),
#  ('ken', 'VERB'),
#  ('full', 'ADJ'),
#  ('of', 'ADP'),
#  ('little', 'ADJ'),
#  ('gentlemen', 'ADJ'),
#  ('little', 'ADJ'),
#  ('caps', 'NOUN'),
#  ('of', 'ADP'),
#  ('blue', 'NOUN'),
#  ('they', 'PRON'),
#  ('wear', 'VERB'),
#  ('and', 'CONJ'),
#  ('green', 'ADJ'),
#  ('ribbons', 'NOUN'),
#  ('very', 'ADV'),
#  ('fair', 'ADJ'),
#  ('flax', 'NOUN'),
#  ('from', 'ADP'),
#  ('house', 'NOUN'),
#  ('to', 'PRT'),
#  ('house', 'NOUN'),
#  ('he', 'PRON'),
#  ('goes', 'VERB'),
#  ('a', 'DET'),
#  ('messenger', 'NOUN'),
#  ('small', 'ADJ'),
#  ('and', 'CONJ'),
#  ('slight', 'ADJ'),
# ...

# %%
ctr=0
for word in tags:
    if word[0]=="or":
        if tags[ctr-1][1]=="NOUN" and tags[ctr+1][1]=="NOUN":
            print(tags[ctr-1][0]+" "+word[0]+" "+tags[ctr+1][0])
    ctr=ctr+1
# Out:
# ship or part
# rest or food
# food or clothes
# food or water
# queens or princesses
# catholics or protestants
# door or driving
# rank or wealth

# %%
tags

# %%
import nltk
gut=ntlk.corpus.gutenberg

# %%
f=open('../Downloads/example.txt').read()
